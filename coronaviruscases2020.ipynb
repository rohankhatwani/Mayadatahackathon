# %%
import pandas as pd
import geopandas as gpd

data = pd.read_csv('der.csv')
data
# Out:
#            Country,\nOther  Total\nCases  New\nCases  Total\nDeaths  \
# 0                    World       3221617      3433.0       228263.0
# 1                      USA       1064572       378.0        61669.0
# 2                    Spain        236899         NaN        24275.0
# 3                    Italy        203591         NaN        27682.0
# 4                   France        166420         NaN        24087.0
# ..                     ...           ...         ...            ...
# 208              St. Barth             6         NaN            NaN
# 209         Western Sahara             6         NaN            NaN
# 210  Caribbean Netherlands             5         NaN            NaN
# 211               Anguilla             3         NaN            NaN
# 212  Saint Pierre Miquelon             1         NaN            NaN
#
#      New\nDeaths  Total\nRecovered  Active\nCases  Serious,\nCritical  \
# 0          233.0         1005229.0        1988125             59822.0
# 1           13.0          147411.0         855492             18671.0
# 2            NaN          132929.0          79695              7764.0
# 3            NaN           71252.0         104657              1795.0
# 4            NaN           48228.0          94105              4207.0
# ..           ...               ...            ...                 ...
# 208          NaN               6.0              0                 NaN
# 209          NaN               5.0              1                 NaN
# 210          NaN               NaN              5                 NaN
# 211          NaN               3.0              0                 NaN
# 212          NaN               NaN              1                 NaN
#
#      Tot Cases/\n1M pop  Deaths/\n1M pop  Total\nTests  Tests/\n1M pop
# 0                 413.0             29.3           NaN             NaN
# 1                3216.0            186.0     6139911.0         18549.0
# 2                5067.0            519.0     1414477.0         30253.0
# 3                3367.0            458.0     1910761.0         31603.0
# 4                2550.0            369.0      463662.0          7103.0
# ..                  ...              ...           ...             ...
# 208               607.0              NaN           NaN             NaN
# 209                10.0              NaN           NaN             NaN
# 210               191.0              NaN         110.0          4195.0
# 211               200.0              NaN           NaN             NaN
# 212               173.0              NaN           NaN             NaN
#
# [213 rows x 12 columns]

# %%
for data_cases in data:
    print(data_cases)
# Out:
# Country,
# Other
# Total
# Cases
# New
# Cases
# Total
# Deaths
# New
# Deaths
# Total
# Recovered
# Active
# Cases
# Serious,
# Critical
# Tot Cases/
# 1M pop
# Deaths/
# 1M pop
# Total
# Tests
# Tests/
# 1M pop

# %%
data_cases = data[['Country,\nOther', 'Total\nCases' ]]

# %%
data_cases
# Out:
#            Country,\nOther  Total\nCases
# 0                    World       3221617
# 1                      USA       1064572
# 2                    Spain        236899
# 3                    Italy        203591
# 4                   France        166420
# ..                     ...           ...
# 208              St. Barth             6
# 209         Western Sahara             6
# 210  Caribbean Netherlands             5
# 211               Anguilla             3
# 212  Saint Pierre Miquelon             1
#
# [213 rows x 2 columns]

# %%
world_data = gpd.read_file(r'/home/rohan/Desktop/Demo/Coronavirus Cases March 2020/World_Map.shp')
world_data.plot()

# %%
world_data
# Out:
#                                      NAME  \
# 0                     Antigua and Barbuda
# 1                                 Algeria
# 2                              Azerbaijan
# 3                                 Albania
# 4                                 Armenia
# ..                                    ...
# 240                      Saint Barthelemy
# 241                              Guernsey
# 242                                Jersey
# 243  South Georgia South Sandwich Islands
# 244                                Taiwan
#
#                                               geometry
# 0    MULTIPOLYGON (((-61.68667 17.02444, -61.73806 ...
# 1    POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 2    MULTIPOLYGON (((45.08332 39.76804, 45.26639 39...
# 3    POLYGON ((19.43621 41.02107, 19.45055 41.06000...
# 4    MULTIPOLYGON (((45.57305 40.63249, 45.52888 40...
# ..                                                 ...
# 240  POLYGON ((-63.02834 18.01555, -63.03334 18.015...
# 241  POLYGON ((-2.59083 49.42249, -2.59722 49.42249...
# 242  POLYGON ((-2.01500 49.21416, -2.02111 49.17722...
# 243  MULTIPOLYGON (((-27.32584 -59.42722, -27.29806...
# 244  MULTIPOLYGON (((121.57639 22.00139, 121.57027 ...
#
# [245 rows x 2 columns]

# %%
for items in data_cases['Country,\nOther'].tolist():
    world_data_list = world_data['NAME'].tolist()
    if items in world_data_list:
        pass
    else:
        print(items + ' is not in the world_data list')
# Out:
# World is not in the world_data list
# USA is not in the world_data list
# UK is not in the world_data list
# Iran is not in the world_data list
# UAE is not in the world_data list
# S. Korea is not in the world_data list
# Czechia is not in the world_data list
# Moldova is not in the world_data list
# North Macedonia is not in the world_data list
# Ivory Coast is not in the world_data list
# Diamond Princess is not in the world_data list
# Channel Islands is not in the world_data list
# DRC is not in the world_data list
# Tanzania is not in the world_data list
# Réunion is not in the world_data list
# Vietnam is not in the world_data list
# Faeroe Islands is not in the world_data list
# Myanmar is not in the world_data list
# Brunei is not in the world_data list
# Cabo Verde is not in the world_data list
# Eswatini is not in the world_data list
# Sint Maarten is not in the world_data list
# Libya is not in the world_data list
# CAR is not in the world_data list
# Macao is not in the world_data list
# Syria is not in the world_data list
# South Sudan is not in the world_data list
# Laos is not in the world_data list
# Curaçao is not in the world_data list
# St. Vincent Grenadines is not in the world_data list
# Falkland Islands is not in the world_data list
# Turks and Caicos is not in the world_data list
# Vatican City is not in the world_data list
# MS Zaandam is not in the world_data list
# St. Barth is not in the world_data list
# Caribbean Netherlands is not in the world_data list
# Saint Pierre Miquelon is not in the world_data list

# %%
world_data.replace('Korea, Republic of', 'S. Korea', inplace = True)
world_data.replace('Iran (Islamic Republic of)', 'Iran', inplace = True)
world_data.replace('United States', 'USA', inplace = True)
world_data.replace('United Kingdom', 'U.K.', inplace = True)
world_data.replace('United Arab Emirates', 'U.A.E.', inplace = True)
world_data.replace('Viet Nam', 'Vietnam', inplace = True)
world_data.replace('Macau', 'Macao', inplace = True)
world_data.replace('The former Yugoslav Republic of Macedonia', 'North Macedonia', inplace = True)
world_data.replace('Czech Republic', 'Czechia', inplace = True)
world_data.replace('Czech Republic', 'Czechia', inplace = True)
world_data.replace('Palestine', 'State of Palestine', inplace = True)

# %%
data_cases.rename(columns = {'Country,\nOther': 'NAME'}, inplace = True)
# Out:
# /home/rohan/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
combined = world_data.merge(data_cases, on = 'NAME')

# %%
combined
# Out:
#                     NAME                                           geometry  \
# 0    Antigua and Barbuda  MULTIPOLYGON (((-61.68667 17.02444, -61.73806 ...
# 1                Algeria  POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 2             Azerbaijan  MULTIPOLYGON (((45.08332 39.76804, 45.26639 39...
# 3                Albania  POLYGON ((19.43621 41.02107, 19.45055 41.06000...
# 4                Armenia  MULTIPOLYGON (((45.57305 40.63249, 45.52888 40...
# ..                   ...                                                ...
# 177           San Marino  POLYGON ((12.41580 43.95795, 12.45055 43.97972...
# 178       Western Sahara  POLYGON ((-15.74200 21.33828, -15.89222 21.338...
# 179               Serbia  POLYGON ((20.07142 42.56091, 20.10583 42.64278...
# 180         Saint Martin  POLYGON ((-63.00667 18.08056, -63.01146 18.067...
# 181               Taiwan  MULTIPOLYGON (((121.57639 22.00139, 121.57027 ...
#
#      Total\nCases
# 0              24
# 1            3848
# 2            1766
# 3             766
# 4            1932
# ..            ...
# 177           563
# 178             6
# 179          8724
# 180            38
# 181           429
#
# [182 rows x 3 columns]

# %%
combined.to_file(r'/home/rohan/Desktop/Demo/Coronavirus Cases March 2020/combined.shp')

# %%
ax=combined.plot(column='Total\nCases',cmap='OrRd',figsize=(10,10),legend=True,edgecolor='black',linewidth=0.4)
